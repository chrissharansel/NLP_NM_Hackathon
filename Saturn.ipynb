# %%
# !pip install transformers datasets sacrebleu sentencepiece --quiet

# %%
# !pip install -U datasets fsspec

# %%
from datasets import load_dataset
ds = load_dataset("ai4bharat/samanantar", "ta")
print(ds['train'][0])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# train-00000-of-00004.parquet:   0%|          | 0.00/189M [00:00<?, ?B/s]
# train-00001-of-00004.parquet:   0%|          | 0.00/189M [00:00<?, ?B/s]
# train-00002-of-00004.parquet:   0%|          | 0.00/188M [00:00<?, ?B/s]
# train-00003-of-00004.parquet:   0%|          | 0.00/188M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5264867 [00:00<?, ? examples/s]
# ...

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast
import torch

model_name = "facebook/mbart-large-50-many-to-many-mmt"
tokenizer = MBart50TokenizerFast.from_pretrained(model_name)
model = MBartForConditionalGeneration.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

max_length = 128  # adjust based on your data

# Set source and target languages — example English to Tamil
src_lang = "en_XX"
tgt_lang = "ta_IN"

tokenizer.src_lang = src_lang
tokenizer.tgt_lang = tgt_lang
# Out:
# tokenizer_config.json:   0%|          | 0.00/529 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
    inputs = examples["en"]
    targets = examples["ta"]

    model_inputs = tokenizer(inputs, max_length=max_length, padding="max_length", truncation=True)

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_length, padding="max_length", truncation=True)

    model_inputs["labels"] = labels["input_ids"]

    # Replace padding token id's of the labels by -100 so they are ignored by the loss
    model_inputs["labels"] = [
        [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in model_inputs["labels"]
    ]

    return model_inputs

tokenized_datasets = ds.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/5264867 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-0bd710657678> in <cell line: 0>()
#      17     return model_inputs
#      18
# ---> 19 tokenized_datasets = ds.map(preprocess_function, batched=True)
#
# /usr/local/lib/python3.11/dist-packages/datasets/dataset_dict.py in map(self, function, with_indices, with_rank, with_split, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc, try_original_type)
#     942                 function = bind(function, split)
#     943
# --> 944             dataset_dict[split] = dataset.map(
#     945                 function=function,
#     946                 with_indices=with_indices,
#
# ...

# %%
/root/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-en-indic-1B/tokenization_indictrans.py
# Out:
#   File "<ipython-input-28-77dd9c32389e>", line 1
#     root/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-en-indic-1B/tokenization_indictrans.py()
#                                                                                         ^
# SyntaxError: invalid decimal literal

# %%
# !pip install -q transformers sentencepiece

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Use correct model
model_name = "ai4bharat/indictrans2-en-indic-1B"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# The repository for ai4bharat/indictrans2-en-indic-1B contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/ai4bharat/indictrans2-en-indic-1B.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] Y
# tokenization_indictrans.py:   0%|          | 0.00/8.04k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-1B:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# dict.SRC.json:   0%|          | 0.00/645k [00:00<?, ?B/s]
# dict.TGT.json:   0%|          | 0.00/3.39M [00:00<?, ?B/s]
# model.SRC:   0%|          | 0.00/759k [00:00<?, ?B/s]
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-04a5e75e77f8> in <cell line: 0>()
# ----> 1 print(tokenizer._tokenizer.pre_tokenizer)
#       2 try:
#       3     from transformers.models.indictrans.tokenization_indictrans import LANGUAGE_TAGS
#       4     print("LANGUAGE_TAGS:", LANGUAGE_TAGS)
#       5 except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in __getattr__(self, key)
#    1106
#    1107         if key not in self.__dict__:
# -> 1108             raise AttributeError(f"{self.__class__.__name__} has no attribute {key}")
#    1109         else:
#    1110             return super().__getattr__(key)
#
# AttributeError: IndicTransTokenizer has no attribute _tokenizer

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "ai4bharat/indictrans2-en-indic-1B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True)

# Import LANGUAGE_TAGS directly from the custom tokenizer module
import sys

# Get the full path of the tokenizer module folder used by transformers
import transformers
path = transformers.__path__[0] + "/modules/transformers_modules/ai4bharat/indictrans2-en-indic-1B/tokenization_indictrans.py"

import importlib.util
spec = importlib.util.spec_from_file_location("tokenization_indictrans", path)
token_module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(token_module)

print("LANGUAGE_TAGS:", token_module.LANGUAGE_TAGS)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-9053892ec551> in <cell line: 0>()
#      15 spec = importlib.util.spec_from_file_location("tokenization_indictrans", path)
#      16 token_module = importlib.util.module_from_spec(spec)
# ---> 17 spec.loader.exec_module(token_module)
#      18
#      19 print("LANGUAGE_TAGS:", token_module.LANGUAGE_TAGS)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in get_data(self, path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/lib/python3.11/dist-packages/transformers/modules/transformers_modules/ai4bharat/indictrans2-en-indic-1B/tokenization_indictrans.py'

# %%
translated_text = translate("Please take this medicine twice a day after food.", tgt_lang="__ta__")
print("Tamil:", translated_text)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-690eae0c0328> in <cell line: 0>()
# ----> 1 translated_text = translate("Please take this medicine twice a day after food.", tgt_lang="__ta__")
#       2 print("Tamil:", translated_text)
#       3
#       4
#
# <ipython-input-17-ae9c11e6bab6> in translate(text, src_lang, tgt_lang)
#       8 def translate(text, src_lang="__en__", tgt_lang="__ta__"):
#       9     tagged_text = f"{src_lang} {tgt_lang} {text}"
# ---> 10     inputs = tokenizer(tagged_text, return_tensors="pt")
#      11     output_ids = model.generate(**inputs, max_length=256)
#      12     translated = tokenizer.decode(output_ids[0], skip_special_tokens=True)
#
# ...
